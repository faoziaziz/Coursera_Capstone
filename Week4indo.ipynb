# %% [markdown]
# # Business Analysis Restaurants around the dock in Jakarta

# %% [markdown]
# ## Introduction
# ### Background
# Indonesia has many islands, this gives Indonesia many docks. But not all docks can be utilized properly. For entrepreneurs, this project can be a reference before you invest in various islands around Jakarta.
#
# ### Problem
# How do you determine the best investment, especially in restaurants on the island around Jakarta?
#
# ### Interest
# This project will be a description of the best location to be used as a reference for investment.

# %% [markdown]
# ## Data

# %% [markdown]
# I used a dataset from the Indonesian Ministry of Transportation to get traffic data for people going in and out of the dock. Available data is only available for 2018 and is still enumerated every month. I use pandas from python to convert them to dataframes

# %%
import pandas as pd

# %%
csv_dict = {
    'JAN':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/708e44a2-9582-4aab-963d-6dd1d9261494/download/revisi-KPI-DATA-PENUMPANG-KAPAL-DARI-DAN--KE-KEPULAUAN-SERIBU-JANUARI.csv",
    'FEB':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/0d54f31f-8765-44d8-b202-d750dd65f14a/download/revisi-DATA-PENUMPANG-KAPAL-DARI-DAN--KE-KEPULAUAN-SERIBU-PERIODE-FEBRUARI-2018.csv",
    'MAR':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/c812c995-5cfb-4ff3-a89d-0a554e34cf94/download/revisi-PENUMPANG-KAPAL-DARI-DAN--KE-KEPULAUAN-SERIBU-PERIODE-MARET-2018.csv",
    'APR':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/8e64f989-b854-422b-92e9-d8002de351ab/download/revisi-KPI-DATA-PNP-APRIL-2018.csv",
    'MAY':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/a8acac92-4e39-4875-a51d-14cd75edaefe/download/Revisi-KPIDATAPENUMPANGMEI2018k.csv",
    'JUN':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/d18d6bab-2a1d-43b8-bc21-3f32270c413a/download/revisi-Juni-2018-Data-Penumpang-Kapal-dari-dan-ke-Kepulauan-Seribu.csv",
    'JUL':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/d933ef6d-3328-4d10-bde8-0cb54b948a93/download/revisi-Data-KPI-Penumpang-dari-dan-ke-Kepulauanan-Seribu-Juli-2018.csv",
    'AUG':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/56acb92b-5e39-4ae1-9c63-adf42790321c/download/revisi-Data-KPI-Penumpang-dari-dan-ke-Kepulauanan-Seribu-Agustus-2018.csv",
    'SEP':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/b15f51dc-42f2-4b25-ae30-aa6a4c2b36e1/download/revisi-Data-KPI-Jumlah-Penumpang-Periode-September-2018-pulau-seibu.csv",
    'OCT':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/5365e1a8-4434-43bb-937f-84e05da7a4eb/download/revisi-KPI-PENUMPANG-DARI-DAN-KE-KEPULAUAN-SERIBU-OKTOBER.csv",
    'NOV':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/ed9d4c2e-73b1-413c-96c8-bd54df752f18/download/revisi-Data-KPI-Jumlah-Penumpang-Kepulauan-Seribu-Periode-November-2018i-Final.csv",
    'DEC':"https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/04aba050-d45c-47e9-8699-2d95e335d6b0/download/revisi-Data-Penumpang-Dari-dan-Ke-Kepulauan-Seribu-Bulan-Desember-2018.csv"
}

# %%
# list for all datassheet 
url=["https://data.jakarta.go.id/dataset/a53db196-26fd-4a64-86c6-4649d89dd00f/resource/04aba050-d45c-47e9-8699-2d95e335d6b0/download/revisi-Data-Penumpang-Dari-dan-Ke-Kepulauan-Seribu-Bulan-Desember-2018.csv"]

# %%
# Read as datafame 
df_jan = pd.read_csv(csv_dict['JAN'])
df_feb = pd.read_csv(csv_dict['FEB'])
df_mar = pd.read_csv(csv_dict['MAR'])
df_apr = pd.read_csv(csv_dict['APR'])
df_may = pd.read_csv(csv_dict['MAY'])
df_jun = pd.read_csv(csv_dict['JUN'])
df_jul = pd.read_csv(csv_dict['JUL'])
df_aug = pd.read_csv(csv_dict['AUG'])
df_sep = pd.read_csv(csv_dict['SEP'])
df_oct = pd.read_csv(csv_dict['OCT'])
df_nov = pd.read_csv(csv_dict['NOV'])
df_dec = pd.read_csv(csv_dict['DEC'])


# because some unneccessary column on december dataframe 
# so i add filter to this frame
df_dec = df_dec.iloc[:,0:5]

# %% [markdown]
# ## Data Preprocessing amd Cleaning

# %% [markdown]
# Concate the dataframe to df_2018

# %%
## after get data from Indonesian Ministry of Transportation we still combine this data

frames = [df_jan, df_feb, df_mar, df_apr, df_may, df_jun, df_jul, df_aug, df_sep, df_oct, df_nov, df_dec]
df_2018 = pd.concat(frames)

df_2018.head(10)
# Out:
#       tanggal       pelabuhan  kapal_berangkat  kapal_tiba  penumpang_naik  \
# 0  2018-01-01  P. MUARA ANGKE             12.0        32.0          1370.0
# 1  2018-01-02  P. MUARA ANGKE             15.0        14.0           841.0
# 2  2018-01-03  P. MUARA ANGKE             13.0         6.0          1013.0
# 3  2018-01-04  P. MUARA ANGKE              7.0        10.0           811.0
# 4  2018-01-05  P. MUARA ANGKE             12.0        13.0          1017.0
# 5  2018-01-06  P. MUARA ANGKE             18.0         7.0          2794.0
# 6  2018-01-07  P. MUARA ANGKE              9.0        13.0           872.0
# 7  2018-01-08  P. MUARA ANGKE              5.0         6.0           278.0
# 8  2018-01-09  P. MUARA ANGKE              4.0         5.0           315.0
# 9  2018-01-10  P. MUARA ANGKE              5.0         6.0           301.0
#
#    penumpang_turun
# 0           7783.0
# 1           2303.0
# 2            981.0
# 3           1092.0
# 4            763.0
# 5            678.0
# ...

# %% [markdown]
# ### Remove any row which has NaN

# %%
df_2018.dropna()
df_2018.shape
# Out:
# (3429, 5)

# %%
### Translate Coloum to English

df_2018.columns = [ 'date', 'port', 'ship_dep', 'ship_arr','pass_board', 'pas_down']

# %% [markdown]
# # Methodology
#
# 1. I combine all the datasets every month to make it 2018 data.
# 2. I plot it to get a graph of the traffic of people on the dock.
# 3.  I use the Foursquare API to be able to track the location of the nearest venue as a consideration for creating a business restaurant.

# %% [markdown]
# ### Exploratory data Analsis

# %% [markdown]
# This will give statistic of all port traffic

# %%
df_2018.describe()
# Out:
#           ship_dep     ship_arr   pass_board     pas_down
# count  3249.000000  3249.000000  3249.000000  2997.000000
# mean      6.069252     6.513389   351.377347   362.408742
# std       5.634807    12.051813   616.000190   639.618620
# min       0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     3.000000    88.000000    97.000000
# 50%       4.000000     4.000000   153.000000   160.000000
# 75%       7.000000     7.000000   370.000000   373.000000
# max      94.000000   570.000000  7754.000000  8213.000000

# %%
df_2018.head(10)
# Out:
#                       port  ship_dep  ship_arr  pass_board  pas_down
# date
# 2018-01-01  P. MUARA ANGKE      12.0      32.0      1370.0    7783.0
# 2018-01-02  P. MUARA ANGKE      15.0      14.0       841.0    2303.0
# 2018-01-03  P. MUARA ANGKE      13.0       6.0      1013.0     981.0
# 2018-01-04  P. MUARA ANGKE       7.0      10.0       811.0    1092.0
# 2018-01-05  P. MUARA ANGKE      12.0      13.0      1017.0     763.0
# 2018-01-06  P. MUARA ANGKE      18.0       7.0      2794.0     678.0
# 2018-01-07  P. MUARA ANGKE       9.0      13.0       872.0    2167.0
# 2018-01-08  P. MUARA ANGKE       5.0       6.0       278.0     376.0
# 2018-01-09  P. MUARA ANGKE       4.0       5.0       315.0     238.0
# 2018-01-10  P. MUARA ANGKE       5.0       6.0       301.0     245.0

# %% [markdown]
# ### get unique port name
#
# get unique port name to search it on Foursquare API

# %%
name_of_port=df_2018['port'].unique()
name_of_port
# Out:
# array(['P. MUARA ANGKE', 'MARINA/ANCOL', 'UNTUNG/JAWA', 'LANCANG', 'PARI',
#        'TIDUNG/PAYUNG', 'PRAMUKA/PANGGANG', 'KELAPA', 'HARAPAN',
#        'MARINA ANCOL', 'UNTUNG JAWA', nan, 'TIDUNG / PAYUNG',
#        'P.MUARA ANGKE'], dtype=object)

# %% [markdown]
# ### Make dataset form name_of_port trully i use google

# %%
port_dict= {'P. MUARA ANGKE':[-6.104273, 106.776137],
               'MARINA/ANCOL': [-6.120832, 106.829338],
               'UNTUNG/JAWA':[-5.979314,106.705954],
               'LANCANG':[-5.927591, 106.583551],
               'PARI':[-5.858461, 106.619455],
               'TIDUNG/PAYUNG':[-5.799234, 106.499728], 
               'PRAMUKA/PANGGANG':[-5.742694, 106.613396], 
               'KELAPA':[-5.652885, 106.571970], 
               'HARAPAN':[-5.649968, 106.578331]
              }

df_port_dict=pd.DataFrame.from_dict(port_dict, orient='index')

# save to csv file
df_port_dict.to_csv("df_port_dict.csv")

# %%
# rad the dataseet
df_port_read = pd.read_csv("df_port_dict.csv")

df_port_read
# Out:
#          Unnamed: 0         0           1
# 0    P. MUARA ANGKE -6.104273  106.776137
# 1      MARINA/ANCOL -6.120832  106.829338
# 2       UNTUNG/JAWA -5.979314  106.705954
# 3           LANCANG -5.927591  106.583551
# 4              PARI -5.858461  106.619455
# 5     TIDUNG/PAYUNG -5.799234  106.499728
# 6  PRAMUKA/PANGGANG -5.742694  106.613396
# 7            KELAPA -5.652885  106.571970
# 8           HARAPAN -5.649968  106.578331

# %%
df_port_read.columns=["Port", "lat", "long"]

df_port_read
# Out:
#                Port       lat        long
# 0    P. MUARA ANGKE -6.104273  106.776137
# 1      MARINA/ANCOL -6.120832  106.829338
# 2       UNTUNG/JAWA -5.979314  106.705954
# 3           LANCANG -5.927591  106.583551
# 4              PARI -5.858461  106.619455
# 5     TIDUNG/PAYUNG -5.799234  106.499728
# 6  PRAMUKA/PANGGANG -5.742694  106.613396
# 7            KELAPA -5.652885  106.571970
# 8           HARAPAN -5.649968  106.578331

# %% [markdown]
# ## Modeling

# %% [markdown]
# This section just give venues details of each Neighboorhod.

# %% [markdown]
# ###  Plot the grafic

# %% [markdown]
# Just give information about the traffict every day on 2018

# %%
df_2018.plot.line()

# %% [markdown]
# gambar diatas adalah total plot grafik

# %% [markdown]
# ## use the Foursquare API to see the venues around the dock

# %%
import requests

# %%
# Define Foursquare Credentials and Version
LIMIT = 100

CLIENT_ID = 'GXHXHSPVOJFOQCKG5YAXDBXQRTQU4DLQUZGDNO505K013EM1' # your Foursquare ID
CLIENT_SECRET = 'WYZW5XP0FG1QSNN0R2T1YFKIIG0MLE3XUCLCM04HMRY20C55' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %%
neighborhood_name=df_port_read.loc[0, 'Port']
neighborhood_lat=df_port_read.loc[0, 'lat']
neighborhood_long=df_port_read.loc[0, 'long']

LIMIT=100
radius=500
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_lat, 
    neighborhood_long, 
    radius, 
    LIMIT)
results = requests.get(url).json()

# %%
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ec28f04963d29001b87cd8c'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Penjaringan',
#   'headerFullLocation': 'Penjaringan, Jakarta',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 16,
#   'suggestedBounds': {'ne': {'lat': -6.099772995499996,
#     'lng': 106.78065421501165},
#    'sw': {'lat': -6.108773004500004, 'lng': 106.77161978498836}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5404607a498e68e95cafbcac',
#        'name': "Gold's Gym",
#        'location': {'address': 'BayWalk Mall, 4th Floor, Unit 24-25',
#         'lat': -6.107240740457599,
#         'lng': 106.77891268714906,
# ...

# %% [markdown]
# ### Get mapp

# %%
# import some dependency

from pandas import json_normalize
import folium
from geopy.geocoders import Nominatim 
import requests

# %%
venues = results['response']['groups'][0]['items']
nearby_venues = json_normalize(venues)
nearby_venues.shape[0]
# Out:
# 16

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]
# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
nearby_venues.head()
# Out:
#                                  name            categories       lat  \
# 0                          Gold's Gym  Gym / Fitness Center -6.107241
# 1   Ikan Bakar & Sea Food Muara Angke    Seafood Restaurant -6.105609
# 2                      TOUS les JOURS                Bakery -6.107468
# 3                      Farmers Market           Supermarket -6.107846
# 4  Pusat Jajan Serba Ikan Muara Angke                Arcade -6.105767
#
#           lng
# 0  106.778913
# 1  106.774350
# 2  106.779257
# 3  106.778886
# 4  106.774615

# %%
### add map using folium

venues_map = folium.Map(location=[neighborhood_lat, neighborhood_long], zoom_start=15)
# add a red circle marker to represent the BEDOKVILLE
folium.features.CircleMarker(
    [neighborhood_lat, neighborhood_long],
    radius=10,
    color='red',
    popup='BEDOKVILLE',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add all venues as blue circle markers
for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The picture above is a picture showing the venue area for a map near the Angkl Estuary Cave. The picture above is an example of a port.

# %% [markdown]
# # Untuk multiple port

# %% [markdown]
# This code will show the total venue in every port

# %%
count_venue=[]
for i in range(0, df_port_read.shape[0]):
    neighborhood_name=df_port_read.loc[i, 'Port']
    neighborhood_lat=df_port_read.loc[i, 'lat']
    neighborhood_long=df_port_read.loc[i, 'long']

    LIMIT=100
    radius=500
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        neighborhood_lat, 
        neighborhood_long, 
        radius, 
        LIMIT)
    results = requests.get(url).json()
    venues = results['response']['groups'][0]['items']
    nearby_venues = json_normalize(venues)
    count_venue.append(nearby_venues.shape[0])
    print(count_venue)
# Out:
# [16]
# [16, 25]
# [16, 25, 4]
# [16, 25, 4, 2]
# [16, 25, 4, 2, 4]
# [16, 25, 4, 2, 4, 6]
# [16, 25, 4, 2, 4, 6, 5]
# [16, 25, 4, 2, 4, 6, 5, 2]
# [16, 25, 4, 2, 4, 6, 5, 2, 2]

# %%
# addd counted venue to dataset

import numpy as np

df_port_read["count"]=count_venue
df_port_read
# Out:
#                Port       lat        long  count
# 0    P. MUARA ANGKE -6.104273  106.776137     16
# 1      MARINA/ANCOL -6.120832  106.829338     25
# 2       UNTUNG/JAWA -5.979314  106.705954      4
# 3           LANCANG -5.927591  106.583551      2
# 4              PARI -5.858461  106.619455      4
# 5     TIDUNG/PAYUNG -5.799234  106.499728      6
# 6  PRAMUKA/PANGGANG -5.742694  106.613396      5
# 7            KELAPA -5.652885  106.571970      2
# 8           HARAPAN -5.649968  106.578331      2

# %%
# save into new datasets

df_port_read.to_csv("add_count.csv")

# %% [markdown]
# ### get plot for every port

# %%
df_2018.groupby('port')['pas_down'].plot(legend=True, figsize=(15,15))
# Out:
# port
# HARAPAN             AxesSubplot(0.125,0.125;0.775x0.755)
# KELAPA              AxesSubplot(0.125,0.125;0.775x0.755)
# LANCANG             AxesSubplot(0.125,0.125;0.775x0.755)
# MARINA ANCOL        AxesSubplot(0.125,0.125;0.775x0.755)
# MARINA/ANCOL        AxesSubplot(0.125,0.125;0.775x0.755)
# P. MUARA ANGKE      AxesSubplot(0.125,0.125;0.775x0.755)
# P.MUARA ANGKE       AxesSubplot(0.125,0.125;0.775x0.755)
# PARI                AxesSubplot(0.125,0.125;0.775x0.755)
# PRAMUKA/PANGGANG    AxesSubplot(0.125,0.125;0.775x0.755)
# TIDUNG / PAYUNG     AxesSubplot(0.125,0.125;0.775x0.755)
# TIDUNG/PAYUNG       AxesSubplot(0.125,0.125;0.775x0.755)
# UNTUNG JAWA         AxesSubplot(0.125,0.125;0.775x0.755)
# UNTUNG/JAWA         AxesSubplot(0.125,0.125;0.775x0.755)
# Name: pas_down, dtype: object

# %%
df_port_read.plot(x='Port',y='count', figsize=(15,15))

# %% [markdown]
# # Result

# %% [markdown]
# This session is to show a plot of the picture, that traffic in the marina port is seen less than in the coconut harbor but for venues in the marina port more, than in the coconut harbor.

# %%
## Show all mapp

count_venue=[]
for i in range(0, df_port_read.shape[0]):
    neighborhood_name=df_port_read.loc[i, 'Port']
    neighborhood_lat=df_port_read.loc[i, 'lat']
    neighborhood_long=df_port_read.loc[i, 'long']

    LIMIT=100
    radius=500
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        neighborhood_lat, 
        neighborhood_long, 
        radius, 
        LIMIT)
    results = requests.get(url).json()
    venues = results['response']['groups'][0]['items']
    nearby_venues = json_normalize(venues)
    
    # add some edgy
    # filter columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    nearby_venues =nearby_venues.loc[:, filtered_columns]
    # filter the category for each row
    nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)
    # clean columns
    nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]
    
    ### add map using folium

    venues_map = folium.Map(location=[neighborhood_lat, neighborhood_long], zoom_start=15)
    # add a red circle marker to represent the BEDOKVILLE
    folium.features.CircleMarker(
        [neighborhood_lat, neighborhood_long],
        radius=10,
        color='red',
        popup='BEDOKVILLE',
        fill = True,
        fill_color = 'red',
        fill_opacity = 0.6
    ).add_to(venues_map)

    # add all venues as blue circle markers
    for lat, lng, label in zip(nearby_venues.lat, nearby_venues.lng, nearby_venues.categories):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            color='blue',
            popup=label,
            fill = True,
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Discussion
#
# The aim of this project is to help investors to easily determine locations on various docks around Jakarta and the Thousand Islands. Using veneu analysis from Foursquare, we can determine a variety of competitors. Also with the restaurant opportunities that are not yet available in these places.

# %% [markdown]
# # Conclusion
#
#
# This project will help investors to understand business opportunities around ports in the Thousand Islands. Comparison of traffic and the location of the nearest veneu from the pier will give a picture to investors.That from the comparison between Kelapa and Marina ports, there was an investment error.

# %% [markdown]
# # Link Blog and Presentation

# %% [markdown]
# # Reference
#
# 1. https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
# 2. https://medium.com/@aboutiana/a-brief-guide-to-using-foursquare-api-with-a-hands-on-example-on-python-6fc4d5451203
